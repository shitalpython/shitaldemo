# %%
import matplotlib.pyplot as plt

# %%
sizes=[10,20,30,30,80]

# %%
lbl=['Drinks','snanks','Maggi','Rice','Dryfruits']

# %%
explode=(0.1,0,0,0)

# %%
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','gray']

# %%
 plt.pie(sizes,labels=lbl,shadow=True,startangle=140,colors=colors, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0c0e9d30f0>,
# ...
#  [Text(-0.9582242938672082, 0.5401908946314167, 'Drinks'),
#   Text(-1.0990725754525106, -0.04516053463131037, 'snanks'),
#   Text(-0.6263003035372735, -0.9042941610942312, 'Maggi'),
#   Text(0.5303248966154442, -0.9637196189918614, 'Rice'),
#   Text(0.6263002612042085, 0.904294190413463, 'Dryfruits')],
#  [Text(-0.5226677966548408, 0.2946495788898636, '5.9%'),
#   Text(-0.5994941320650057, -0.024633018889805652, '11.8%'),
#   Text(-0.3416183473839673, -0.4932513605968533, '17.6%'),
#   Text(0.2892681254266059, -0.5256652467228334, '17.6%'),
#   Text(0.34161832429320454, 0.4932513765891616, '47.1%')])
