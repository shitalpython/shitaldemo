# %%
import pandas as pd

# %%
d=pd.read_csv("http://bit.ly/imdbratings")

# %%
d.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
d[d.content_rating == "R"]
# Out:
#      star_rating                            title content_rating      genre  \
# 0            9.3         The Shawshank Redemption              R      Crime
# 1            9.2                    The Godfather              R      Crime
# 2            9.1           The Godfather: Part II              R      Crime
# 4            8.9                     Pulp Fiction              R      Crime
# 8            8.9                 Schindler's List              R  Biography
# 9            8.9                       Fight Club              R      Drama
# 16           8.7  One Flew Over the Cuckoo's Nest              R      Drama
# 18           8.7                       Goodfellas              R  Biography
# 20           8.7                       The Matrix              R     Action
# 21           8.7                      City of God              R      Crime
# 23           8.7               The Usual Suspects              R      Crime
# ...

# %%
D.SHAPE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e2be58615753> in <module>
# ----> 1 D.SHAPE
#
# NameError: name 'D' is not defined

# %%
d.shape
# Out:
# (979, 6)

# %%
d.drop('content_rating',axis=1,inplace=True)

# %%
d.head()
# Out:
#    star_rating                     title   genre  duration  \
# 0          9.3  The Shawshank Redemption   Crime       142
# 1          9.2             The Godfather   Crime       175
# 2          9.1    The Godfather: Part II   Crime       200
# 3          9.0           The Dark Knight  Action       152
# 4          8.9              Pulp Fiction   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [raw]
# d.star_rating.avg()

# %%
d.star_rating.max()
# Out:
# 9.3

# %%
d.star_rating.min()
# Out:
# 7.4

# %%
d['star_rating'].sort_values()
# Out:
# 978    7.4
# 950    7.4
# 949    7.4
# 948    7.4
# 947    7.4
# 946    7.4
# 945    7.4
# 944    7.4
# 943    7.4
# 942    7.4
# 941    7.4
# 940    7.4
# 939    7.4
# 938    7.4
# 937    7.4
# 936    7.4
# 935    7.4
# 934    7.4
# 933    7.4
# 932    7.4
# 931    7.4
# 930    7.4
# 951    7.4
# 952    7.4
# 977    7.4
# 954    7.4
# 953    7.4
# 976    7.4
# 975    7.4
# 974    7.4
#       ...
# 36     8.6
# 37     8.6
# 38     8.6
# 39     8.6
# 32     8.6
# 17     8.7
# 15     8.7
# 16     8.7
# 18     8.7
# 24     8.7
# 20     8.7
# 21     8.7
# 22     8.7
# 23     8.7
# 19     8.7
# 14     8.8
# 13     8.8
# 12     8.8
# 11     8.8
# 10     8.8
# 4      8.9
# 5      8.9
# 9      8.9
# 7      8.9
# 8      8.9
# 6      8.9
# 3      9.0
# 2      9.1
# 1      9.2
# 0      9.3
# Name: star_rating, Length: 979, dtype: float64

# %%
d.sort_values('star_rating')
# Out:
#      star_rating                                              title  \
# 978          7.4                                        Wall Street
# 950          7.4                                              Bound
# 949          7.4                                         Home Alone
# 948          7.4                                         Frances Ha
# 947          7.4                                         Eraserhead
# 946          7.4                                    Far from Heaven
# 945          7.4                                       Take Shelter
# 944          7.4                                Terms of Endearment
# 943          7.4                                    The Bucket List
# 942          7.4                                    Raising Arizona
# 941          7.4                                   A Bridge Too Far
# 940          7.4                             Much Ado About Nothing
# 939          7.4                                     Predestination
# ...

# %%
d.sort_values(['star_rating','genre'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-fc2f9b0df178> in <module>
# ----> 1 d[d.sort_values(['star_rating','genre'])]
#
# ~/PycharmProjects/AaravTech/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
# -> 2684             return self._getitem_frame(key)
#    2685         elif is_mi_columns:
#    2686             return self._getitem_multilevel(key)
#
# ~/PycharmProjects/AaravTech/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_frame(self, key)
#    2765     def _getitem_frame(self, key):
#    2766         if key.values.size and not is_bool_dtype(key.values):
# -> 2767             raise ValueError('Must pass DataFrame with boolean values only')
#    2768         return self.where(key)
#    2769
#
# ...

# %%
d[d.star_rating>9.2]
# Out:
#    star_rating                     title  genre  duration  \
# 0          9.3  The Shawshank Redemption  Crime       142
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %%
d[(d.star_rating>9.2) | (d.star_rating == 8.9)]
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration                                        actors_list
# 0       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 4       154  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5        96  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 6       161  [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# 7       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# ...

# %%
d[d.star_rating.isin([9.3,8.9])]
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration                                        actors_list
# 0       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 4       154  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5        96  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 6       161  [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# 7       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# ...
