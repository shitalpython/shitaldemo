# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ex_value=[1800,1200,1400]

# %%
ex_labels=['shopping','rent','petrol']

# %%
plt.xlabel('expenses')
plt.ylabel('costs')
plt.title('Middle class family cost chart')
plt.plot(ex_labels,ex_value,color='green',linestyle='dotted',marker='+',markersize=10)
